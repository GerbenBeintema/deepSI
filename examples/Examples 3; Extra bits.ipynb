# %% [markdown]
# ## Examples 3; Extra bits
#
# Some additional thing included in deepSI which were not discussed in the other examples.
#
# * Hyperparameter search for linear systems
# * Creating your estimator, a more in-depth look into how estimators work
# * CNN and images.
# * Input design.

# %% [markdown]
# ## 1. Hyperparameter search for linear systems
#
# You can also optimize the hyper parameter using deepSI by a grid search. Used very commonly in linear SysID.

# %%
import deepSI
train, test = deepSI.datasets.Silverbox()
Sys = deepSI.fit_systems.Sklearn_io_linear
bestfit, sys, best_sys_choices, best_fit_choices = \
    deepSI.fit_systems.grid_search(Sys,train,sim_val=test,sys_dict_choices=dict(na=[1,2,3,4,5,6],nb=[1,2,3,4,5,6]) )
# Out:
# 0.9338714535599205 {'na': 1, 'nb': 1} {}
# 0.9454436827363305 {'na': 1, 'nb': 2} {}
# 0.9409776357050734 {'na': 1, 'nb': 3} {}
# 0.8507753710955666 {'na': 1, 'nb': 4} {}
# 0.8034919580979644 {'na': 1, 'nb': 5} {}
# 0.815368512263009 {'na': 1, 'nb': 6} {}
# 0.14763950323332964 {'na': 2, 'nb': 1} {}
# 0.14335903007683795 {'na': 2, 'nb': 2} {}
# 0.14038659419514363 {'na': 2, 'nb': 3} {}
# 0.13571190831096455 {'na': 2, 'nb': 4} {}
# 0.13509493478422924 {'na': 2, 'nb': 5} {}
# 0.13257154725710474 {'na': 2, 'nb': 6} {}
# 0.14372875859730513 {'na': 3, 'nb': 1} {}
# 0.15321198336010167 {'na': 3, 'nb': 2} {}
# 0.15268033923036586 {'na': 3, 'nb': 3} {}
# 0.14310446576683072 {'na': 3, 'nb': 4} {}
# 0.1405576406391178 {'na': 3, 'nb': 5} {}
# 0.137065675900539 {'na': 3, 'nb': 6} {}
# 0.14149406777793422 {'na': 4, 'nb': 1} {}
# 0.15519519197051318 {'na': 4, 'nb': 2} {}
# 0.16450387843794212 {'na': 4, 'nb': 3} {}
# 0.15591983814037472 {'na': 4, 'nb': 4} {}
# ...

# %%
Sys = deepSI.fit_systems.SS_linear
bestfit, sys, best_sys_choices, best_fit_choices = \
    deepSI.fit_systems.grid_search(Sys,train,sim_val=test,\
                                   sys_dict_choices=dict(nx=[1,2,3,4,5,6]),\
                                   fit_dict_choices=dict(SS_f=[1,2,3,5,10,20,40]))
# Out:
# 0.9313502745052733 {'nx': 1} {'SS_f': 1}
# 0.9325642598703692 {'nx': 1} {'SS_f': 2}
# 0.9225953921950076 {'nx': 1} {'SS_f': 3}
# 0.9359749880594658 {'nx': 1} {'SS_f': 5}
# 0.9355152450251025 {'nx': 1} {'SS_f': 10}
# 0.9418865923439014 {'nx': 1} {'SS_f': 20}
# 0.9541362021866188 {'nx': 1} {'SS_f': 40}
# Warning! The horizon must be larger than the model order, max_order setted as future
# error shapes (1,1) and (2,) not aligned: 1 (dim 1) != 2 (dim 0) for sys_dict= {'nx': 2} for fit_dict= {'SS_f': 1}
# inf {'nx': 2} {'SS_f': 1}
# 0.13101514383747823 {'nx': 2} {'SS_f': 2}
# 0.1308718142339101 {'nx': 2} {'SS_f': 3}
# 0.13634028222999897 {'nx': 2} {'SS_f': 5}
# 0.20241341043069722 {'nx': 2} {'SS_f': 10}
# 0.8569105805812854 {'nx': 2} {'SS_f': 20}
# 0.8744074564723351 {'nx': 2} {'SS_f': 40}
# Warning! The horizon must be larger than the model order, max_order setted as future
# ...

# %% [markdown]
# ## 2. Creating your estimator, a more in-depth look into how estimators work

# %%
#to be explained later

import deepSI
import numpy as np
from matplotlib import pyplot as plt
from torch import nn
import torch

class NARX_basic(deepSI.fit_systems.System_torch):
    """docstring for NARX"""
    def __init__(self, na=20, nb=20):
        super(NARX_basic, self).__init__()
        self.na, self.nb = na, nb
        self.k0 = max(self.na, self.nb)

        from deepSI.utils import simple_res_net, feed_forward_nn
        self.net = simple_res_net
        self.n_hidden_layers = 2
        self.n_nodes_per_layer = 64
        self.activation = nn.Tanh


    def init_nets(self, nu, ny):
        '''Defined in subclass and initializes networks and returns the parameters

        Parameters
        ----------
        nu : None, int or tuple
            The shape of the input u
        ny : None, int or tuple
            The shape of the output y

        Returns
        -------
        parameters : list
            List of the network parameters
        '''
        assert nu is None
        assert ny is None
        self.NARX_net = self.net(n_in=self.na + self.nb, n_out=1, n_nodes_per_layer=self.n_nodes_per_layer,\
                                     n_hidden_layers=self.n_hidden_layers, activation=self.activation)

    def make_training_data(self, sys_data, **loss_kwargs):
        '''Defined in subclass which converts the normed sys_data into training data

        Parameters
        ----------
        sys_data : System_data or System_data_list
            Already normalized
        loss_kwargs : dict
            loss function settings passed into .fit
        '''
        assert sys_data.normed == True

        uy,Y = sys_data.to_IO_data(na=self.na, nb=self.nb)
        return uy, Y

    def loss(self, uy, Y, **loss_kwargs):
        '''Defined in subclass which take the batch data and calculates the loss based on loss_kwargs

        Parameters
        ----------
        training_data_batch : list
            batch of the training data returned by make_training_data and converted to torch arrays
        loss_kwargs : dict
            loss function settings passed into .fit
        '''
        Yhat = self.NARX_net(uy)[:,0]
        return torch.mean((Y-Yhat)**2)

    def init_state_and_measure(self, sys_data):
        '''Initialize the internal state of the model using the start of sys_data

        Returns
        -------
        Output : an observation (e.g. floats)
            The observation/predicted state at time step k0
        k0 : int
            number of steps that should be skipped

        Notes
        -----
        Example: x0 = encoder(u[t-k0:k0],yhist[t-k0:k0]), and return h(x0), k0
        This function is often overwritten in child. As default it will return self.reset_state(), 0 
        '''
        k0 = max(self.na,self.nb)
        self.yhist = list(sys_data.y[k0-self.na:k0])
        self.uhist = list(sys_data.u[k0-self.nb:k0-1]) #how it is saved, len(yhist) = na, len(uhist) = nb-1
        #when taking an action uhist gets appended to create the current state
        return sys_data.y[k0-1], k0

    def init_state_and_measure_multi(self, sys_data, nf=None, stride=1):
        '''Similar to init_state but to initialize multiple states 
           (used in self.n_step_error and self.one_step_ahead)

            Parameters
            ----------
            sys_data : System_data
                Data used to initialize the state
            nf : int
                skip the nf last states
            stride: int
                number of states between each state
           '''
        k0 = self.k0
        self.yhist = np.array([sys_data.y[k0-self.na+i:k0+i  ] for i in range(0,len(sys_data)-k0-nf+1,stride)]) #+1? #shape = (N,na)
        self.uhist = np.array([sys_data.u[k0-self.nb+i:k0+i-1] for i in range(0,len(sys_data)-k0-nf+1,stride)]) #+1? #shape = 
        return self.yhist[:,-1], k0

    def act_measure(self, action):
        '''Applies the action to the system and returns the new observation, 
        should always be overwritten in subclass'''
        self.uhist.append(action)
        uy = np.concatenate((np.array(self.uhist).flat,np.array(self.yhist).flat),axis=0) #might not be the quickest way
        yout = self.NARX_net(torch.as_tensor(uy,dtype=torch.float32)[None,:])[0,0].detach().numpy()
        self.yhist.append(yout)
        self.yhist.pop(0)
        self.uhist.pop(0)
        return yout

    def act_measure_multi(self, actions):
        '''Applies the actions to the system and returns the new observations'''
        actions = np.array(actions)
        self.uhist = np.append(self.uhist, actions[:,None], axis=1)
        uy = np.concatenate([self.uhist.reshape(self.uhist.shape[0],-1),self.yhist.reshape(self.uhist.shape[0],-1)],axis=1) ######todo MIMO
        yout = self.NARX_net(torch.as_tensor(uy,dtype=torch.float32))[:,0].detach().numpy()
        self.yhist = np.append(self.yhist[:,1:],yout[:,None],axis=1)
        self.uhist = self.uhist[:,1:]
        return yout


sys = NARX_basic()
train, test = deepSI.datasets.Silverbox()
sys.fit(train, test[:1000])
test_sim = sys.apply_experiment(test)
print('NRMS:',test_sim.NRMS(test))
test.plot()
(test-test_sim).plot(show=True)
sys.n_step_error_plot(test)
# Out:
# Initilizing the model and optimizer
# Size of the training array =  20.3 MB
# N_training_samples = 65042, batch_size = 256, N_batch_updates_per_epoch = 254
# Initial Validation sim-NRMS= 1.0770804371947682
#   0%|          | 0/30 [00:00<?, ?it/s]
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.1524777472898243
# Epoch    1, sqrt loss  0.2131, Val sim-NRMS 0.1525, Time Loss: 70.9%, data: 3.6%, val: 25.4%, 116.0 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.12146586680573225
# Epoch    2, sqrt loss 0.04608, Val sim-NRMS 0.1215, Time Loss: 68.4%, data: 3.6%, val: 27.9%, 135.4 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.11357184831072845
# Epoch    3, sqrt loss 0.03275, Val sim-NRMS 0.1136, Time Loss: 67.1%, data: 3.7%, val: 29.0%, 143.3 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.10888747232598889
# ...

# %% [markdown]
# ## 3. CNN and images.

# %%
from deepSI.fit_systems import SS_encoder_CNN_video

sys = SS_encoder_CNN_video()
sys.init_nets(nu=None, ny=(50,50)) #image shape = (height, width)
print(sys.fn) #normal network
print(sys.encoder) #4 blocks of downscaling
print(sys.hn) #4 blocks of downscaling

sys = SS_encoder_CNN_video()
sys.init_nets(nu=None, ny=(3,50,50)) #image shape = (nchannels,height, width)
print(sys.fn) #normal network
print(sys.encoder) #4 blocks of downscaling
print(sys.hn) #4 blocks of downscaling
# Out:
# default_state_net(
#   (net): simple_res_net(
#     (net_lin): Linear(in_features=11, out_features=10, bias=True)
#     (net_non_lin): feed_forward_nn(
#       (net): Sequential(
#         (0): Linear(in_features=11, out_features=64, bias=True)
#         (1): Tanh()
#         (2): Linear(in_features=64, out_features=64, bias=True)
#         (3): Tanh()
#         (4): Linear(in_features=64, out_features=10, bias=True)
#       )
#     )
#   )
# )
# CNN_encoder(
#   (CNN): CNN_chained_downscales(
#     (downblocks): Sequential(
#       (0): Down_Conv_block(
#         (shortcut): Conv2d(20, 26, kernel_size=(3, 3), stride=(2, 2), padding=valid)
#         (conv): Conv2d(20, 20, kernel_size=(3, 3), stride=(1, 1), padding=same)
#         (downscale): Conv2d(20, 26, kernel_size=(3, 3), stride=(2, 2), padding=valid)
#       )
#       (1): Down_Conv_block(
#         (shortcut): Conv2d(26, 35, kernel_size=(3, 3), stride=(2, 2), padding=valid)
# ...

# %%
sys.parameters_with_names
# Out:
# {'encoder': {'params': <generator object Module.parameters at 0x000001CAB6F83C80>},
#  'fn': {'params': <generator object Module.parameters at 0x000001CAB6227740>},
#  'hn': {'params': <generator object Module.parameters at 0x000001CAB6227900>}}

# %% [markdown]
# ## 4. Input design.
#
#
# deepSI provides some simple input generation methods
#
# * `deepSI.exp_design.multisine`
# * `deepSI.exp_design.filtered_signal`
#
# example;

# %%
import deepSI

#fmax = pmax/(N_points_per_period*sample time) #(largest frequecy present in generated signal)
N_points_per_period = 10000
fmax = 2 #2 Hz is the maximal frequency
Ts = 0.01
pmax = int(fmax*(N_points_per_period*Ts))
u = deepSI.exp_design.multisine(N_points_per_period=N_points_per_period, pmin=1, pmax=pmax, n_crest_factor_optim=500)
t = np.arange(N_points_per_period)*Ts
plt.plot(t,u)
plt.xlabel('t')
plt.ylabel('u')
plt.show()
feqs = np.fft.fftfreq(N_points_per_period, d=Ts)
fft_comp = np.fft.fft(u)

plt.plot(feqs, np.abs(fft_comp),'.')#2 Hz is the maximal frequency
plt.xlim(0, fmax*3)
plt.xlabel('Hz')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# # 5. Continuous time state-space models with $1/\tau$ normalization
#
# For continuous time models you need to set the `dt` property of datasets that you are working with as

# %%
import deepSI
from matplotlib import pyplot as plt
train, test = deepSI.datasets.Cascaded_Tanks()
train.dt = 4
test.dt = 4

# %% [markdown]
# Now one can use the CT subspace method as
#
# $$
# \hat{y} (t) = h_\theta(x(t),u(t))\\
# x(t) = \frac{1}{\tau} f_\theta(x(t), u(t)) = f_\text{norm} f_\theta(x(t), u(t))
# $$
#
# where $\frac{1}{\tau}$ is the state-derivative normalization constant.

# %%
#dt/tau = f_norm*dt = 0.03
f_norm = 0.03/train.dt
sys = deepSI.fit_systems.SS_encoder_deriv_general(nx=2, na=5, nb=5, f_norm=f_norm)

sys.fit(train, test[:len(test)//2], epochs=60, batch_size=64) #short optimization (higher epoch is better)
# Out:
# Initilizing the model and optimizer
# Size of the training array =  466.4 kB
# N_training_samples = 995, batch_size = 64, N_batch_updates_per_epoch = 15
# Initial Validation sim-NRMS= 1.0463988823768668
#   0%|          | 0/5000 [00:00<?, ?it/s]
# Epoch    1, sqrt loss   0.674, Val sim-NRMS  1.308, Time Loss: 74.8%, data: 0.7%, val: 24.6%, 10.9 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.7438283185781976
# Epoch    2, sqrt loss  0.3613, Val sim-NRMS 0.7438, Time Loss: 75.4%, data: 0.7%, val: 23.9%, 10.9 batches/sec
# Epoch    3, sqrt loss  0.3031, Val sim-NRMS  0.808, Time Loss: 75.7%, data: 0.5%, val: 23.9%, 11.0 batches/sec
# Epoch    4, sqrt loss  0.2786, Val sim-NRMS 0.8062, Time Loss: 75.8%, data: 0.4%, val: 23.8%, 11.1 batches/sec
# ########## New lowest validation loss achieved ########### sim-NRMS = 0.6174468778953984
# Epoch    5, sqrt loss  0.2526, Val sim-NRMS 0.6174, Time Loss: 75.7%, data: 0.3%, val: 23.9%, 11.2 batches/sec
# ...

# %%
test_p = sys.apply_experiment(test)
print('RMS test',test_p.RMS(test))
test_p.plot()
test.plot()
plt.show()
# Out:
# RMS test 0.42867864332791444

# %%
print(sys.derivn) #this has f(x,u)
#to obtain dx/dt multiply f(x,u)*sys.f_norm
print(sys.fn) #hold the state advance and is the integrator.
# Out:
# default_state_net(
#   (net): simple_res_net(
#     (net_lin): Linear(in_features=3, out_features=2, bias=True)
#     (net_non_lin): feed_forward_nn(
#       (net): Sequential(
#         (0): Linear(in_features=3, out_features=64, bias=True)
#         (1): Tanh()
#         (2): Linear(in_features=64, out_features=64, bias=True)
#         (3): Tanh()
#         (4): Linear(in_features=64, out_features=2, bias=True)
#       )
#     )
#   )
# )
# integrator_RK4(
#   (deriv_base): default_state_net(
#     (net): simple_res_net(
#       (net_lin): Linear(in_features=3, out_features=2, bias=True)
#       (net_non_lin): feed_forward_nn(
#         (net): Sequential(
#           (0): Linear(in_features=3, out_features=64, bias=True)
#           (1): Tanh()
#           (2): Linear(in_features=64, out_features=64, bias=True)
#           (3): Tanh()
#           (4): Linear(in_features=64, out_features=2, bias=True)
#         )
#       )
#     )
#   )
# )

# %%
# you can include custom networks by changing one of the networks 
# e_net=default_encoder_net, f_net=default_state_net, integrator_net=integrator_RK4, h_net=default_output_net, \
# e_net_kwargs={},           f_net_kwargs={},         integrator_net_kwargs={},      h_net_kwargs={},\
# be sure it has the same fingerprint as the original.
